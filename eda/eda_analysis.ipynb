# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/restaurant_classification_medium.csv")
df.head()
# Out:
#    Food_Quality  Service  Ambience Price_Range  Wait_Time Customer_Type  \
# 0             3        5         2         Low         59       Regular
# 1             1        1         3        High         43           New
# 2             5        1         2      Medium         59       Tourist
# 3             3        5         4      Medium         38           New
# 4             2        3         3         Low         10       Tourist
#
#   Day_Type Satisfied
# 0  Weekday        No
# 1  Weekday        No
# 2  Weekend        No
# 3  Weekday        No
# 4  Weekday        No

# %%
df.shape
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_Quality   1000 non-null   int64
#  1   Service        1000 non-null   int64
#  2   Ambience       1000 non-null   int64
#  3   Price_Range    1000 non-null   object
#  4   Wait_Time      1000 non-null   int64
#  5   Customer_Type  1000 non-null   object
#  6   Day_Type       1000 non-null   object
#  7   Satisfied      1000 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB
#         Food_Quality      Service     Ambience Price_Range    Wait_Time  \
# count     1000.00000  1000.000000  1000.000000        1000  1000.000000
# unique           NaN          NaN          NaN           3          NaN
# top              NaN          NaN          NaN         Low          NaN
# freq             NaN          NaN          NaN         421          NaN
# mean         2.98900     3.061000     2.971000         NaN    31.819000
# std          1.41947     1.392558     1.424144         NaN    16.220769
# min          1.00000     1.000000     1.000000         NaN     5.000000
# 25%          2.00000     2.000000     2.000000         NaN    17.000000
# 50%          3.00000     3.000000     3.000000         NaN    32.000000
# 75%          4.00000     4.000000     4.000000         NaN    46.000000
# max          5.00000     5.000000     5.000000         NaN    59.000000
#
#        Customer_Type Day_Type Satisfied
# count           1000     1000      1000
# unique             3        2         2
# top          Regular  Weekday        No
# freq             484      689       860
# mean             NaN      NaN       NaN
# std              NaN      NaN       NaN
# min              NaN      NaN       NaN
# 25%              NaN      NaN       NaN
# 50%              NaN      NaN       NaN
# 75%              NaN      NaN       NaN
# max              NaN      NaN       NaN

# %%
df.isnull().sum()
# Out:
# Food_Quality     0
# Service          0
# Ambience         0
# Price_Range      0
# Wait_Time        0
# Customer_Type    0
# Day_Type         0
# Satisfied        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x="Satisfied", data=df)
plt.title("Target Class Distribution")
plt.show()

df["Satisfied"].value_counts()
# Out:
# Satisfied
# No     852
# Yes    140
# Name: count, dtype: int64

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
sns.countplot(x="Service", hue="Satisfied", data=df)
plt.show()
